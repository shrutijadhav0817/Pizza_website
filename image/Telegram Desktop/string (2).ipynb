# %% [markdown]
# # String:
#
# 1. Reverse a String
# 2. Check if a String is a Palindrome
# 3. Count the Number of Vowels in a String
# 4. Find the Frequency of Characters in a String
# 5. Check if Two Strings are Anagrams
# 6. Remove Duplicate Characters from a String
# 7. Check if a String Contains Only Digits
# 8. Convert the First Letter of Each Word to Uppercase

# %% [markdown]
# ### 1. Reverse a String

# %%
str1 = 'hello'
str1[::-1]
# Out:
# 'olleh'

# %%
str2 = input("Enter a string to reverse: ")
# Method 1: Using slicing
reversed_str2 = str2[::-1]
print("Reversed string:", reversed_str2)
# Out:
# Enter a string to reverse:  erty
# Reversed string: ytre

# %%
str3 = input("Enter a string to reverse: ")
# Method 2: Using reversed() and join()
reversed_str3 = ''.join(reversed(str3))
print("Reversed string:", reversed_str3)
# Out:
# Enter a string to reverse:  werty
# Reversed string: ytrew

# %% [markdown]
# ### 2. Check if a String is a Palindrome

# %%
str1 = input("Enter a string to check palindrome: ")
clean_str = str1.replace(" ", "").lower()

if clean_str == clean_str[::-1]:
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# Enter a string to check palindrome:  oppo
# The string is a palindrome

# %%
# WAP to print given string is palindrome or not
input_string = input("Enter a string: ")
reversed_string = ""

for char in input_string:
    reversed_string = char + reversed_string  # Prepend each character

if input_string == reversed_string:
    print(f"'{input_string}' is a palindrome.")
else:
    print(f"'{input_string}' is not a palindrome.")
# Out:
# Enter a string:  121
# '121' is a palindrome.

# %% [markdown]
# ### 3. Count the Number of Vowels in a String

# %%
str5 = input("Enter the string: ")
count = 0
for i in str5:
    if i.lower() in ['a','e','i','o','u']:
        count += 1
print(f"The no. of Vowels in a string are: {count}")
# Out:
# Enter the string:  dfg
# The no. of Vowels in a string are: 0

# %% [markdown]
# ### 4. Find the Frequency of Characters in a String

# %%
string = input("Enter the string: ")
freq = {}
for char in string:
    if char in freq:
        freq[char]+=1
    else:
        freq[char]=1
print("Character Frequency:")
for key, value in freq.items():
    print(f"{key} : {value}")
# Out:
# Enter the string:  asdfasdfg
# Character Frequency:
# a : 2
# s : 2
# d : 2
# f : 2
# g : 1

# %%
from collections import Counter
string = input("Enter a string: ")
freq = Counter(string)

print("Character Frequency:")
for key, value in freq.items():
    print(f"{key}: {value}")
# Out:
# Enter a string:  werwert
# Character Frequency:
# w: 2
# e: 2
# r: 2
# t: 1

# %% [markdown]
# ### 5. Check if Two Strings are Anagrams

# %%
string1 = input("Enter the first string: ")
string2 = input("Enter the second string: ")

string1 = string1.replace(" ","").lower()
string2 = string2.replace(" ","").lower()

if sorted(string1) == sorted(string2):
    print("Strings are Anagrams")
else:
    print("Strings are not Anagrams")
# Out:
# Enter the first string:  ate
# Enter the second string:  eat
# Strings are Anagrams

# %%
from collections import Counter
string1 = input("Enter the first string: ")
string2 = input("Enter the second string: ")

string1 = string1.replace(" ","").lower()
string2 = string2.replace(" ","").lower()

if Counter(string1) == Counter(string2):
    print("Strings are Anagrams")
else:
    print("Strings are not Anagrams")
# Out:
# Enter the first string:  wert
# Enter the second string:  sdfg
# Strings are not Anagrams

# %% [markdown]
# ### 6. Remove Duplicate Characters from a String

# %%
str6 = input("Enter the string: ")
result = ""
for i in str6:
    if i not in result:
        result += i
print("String after removing duplicates:", result)
# Out:
# Enter the string:  wertywerty
# String after removing duplicates: werty

# %%
str6 = input("Enter the string: ")
result = "".join(dict.fromkeys(str6))
print("String after removing duplicates:", result)
# Out:
# Enter the string:  12341234
# String after removing duplicates: 1234

# %% [markdown]
# ### 7. Check if a String Contains Only Digits

# %%
str7 = input("Enter a string: ")
only_digits = True  # Assume all characters are digits

for ch in str7:
    if ch < '0' or ch > '9':  # Check if character is not a digit
        only_digits = False
        break

if only_digits and str7 != "":  # Ensure string is not empty
    print("The string contains only digits")
else:
    print("The string contains non-digit characters")
# Out:
# Enter a string:  1234
# The string contains only digits

# %%
str7 = input("Enter a string: ").strip()
if str7.isdigit():
    print("The string contains only digits")
else:
    print("The string contains non-digit characters")
# Out:
# Enter a string:  345
# The string contains only digits

# %%
"12345".isdigit()   # True
"12a45".isdigit()   # False
"".isdigit()        # False
# Out:
# False

# %% [markdown]
# ### 8. Convert the First Letter of Each Word to Uppercase

# %%
str8 = input("Enter a string: ")

# Method 1: Using title()
print("Converted string:", str8.title())

# Method 2: Without using title(), manual method
words = str8.split()  # Split string into words
#capitalized_words = [word[0].upper() + word[1:] if word else '' for word in words]
capitalized_words = []

for word in words:
    if word:  # Check if word is not empty
        capitalized_word = word[0].upper() + word[1:]
        capitalized_words.append(capitalized_word)
    else:
        capitalized_words.append('')  # Handle empty words
result = " ".join(capitalized_words)
print("Converted string:", result)
# Out:
# Enter a string:  qwer
# Converted string: Qwer
# Converted string: Qwer

# %%
capitalized_words = []

for word in words:
    if word:  # Check if word is not empty
        capitalized_word = word[0].upper() + word[1:]
        capitalized_words.append(capitalized_word)
    else:
        capitalized_words.append('')  # Handle empty words
